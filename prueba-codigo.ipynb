# %%
frases = {"Un señor bajito con un anillo":"B"} 
print(frases.keys())
print("A: Harry Potter\nB: El señor de los Anillos\nC: El Hobbit")
# Out:
# dict_keys(['Un señor bajito con un anillo'])
# A: Harry Potter
# B: El señor de los Anillos
# C: El Hobbit

# %%
respuesta = input("Escribe aquí tu respuesta")
if respuesta in frases.values():
    print("Correcto")
else:
    print("Incorrecto")
# Out:
# Correcto

# %%
preguntas = {
 "pregunta": "Un señor bajito con un anillo",
 "opciones": {"a": "Harry Potter", "b": "El señor de los Anillos", "c": "Los Vengadores"},
 "respuesta_correcta": "b"
}
